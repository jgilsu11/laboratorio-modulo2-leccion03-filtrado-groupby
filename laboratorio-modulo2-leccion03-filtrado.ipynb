# %% [markdown]
# <div style="text-align: center;">
#   <img src="https://github.com/Hack-io-Data/Imagenes/blob/main/01-LogosHackio/logo_naranja@4x.png?raw=true" alt="esquema" />
# </div>

# %% [markdown]
# # Laboratorio Filtrado de Datos
#
# En este laboratorio usaremos el DataFrame creado en la lección anterior resultado de la unión de los conjuntos de datos compartidos contigo.
#
# **Instrucciones:**
#
# 1. Lee cuidadosamente el enunciado de cada ejercicio.
#
# 2. Implementa la solución en la celda de código proporcionada.

# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_columns", None)

# %%
# Carga el dataset de trabajo
netflix_concat= pd.read_csv("datos/netflix_concat.csv", index_col= 0)    #Contrl espacio para ver por donde voy

# %% [markdown]
# #### Ejercicio 1: ¿Cuáles son todos los títulos lanzados en 2021 que son del tipo 'Movie'?

# %%
netflix_concat.head(2)
# Out:
#              Title        Genre         Premiere  Runtime  IMDB Score  \
# 0  Enter the Anime  Documentary   August 5, 2019       58         2.5
# 1      Dark Forces     Thriller  August 21, 2020       81         2.6
#
#            Language show_id   type            title           director  \
# 0  English/Japanese   s3624  Movie  Enter the Anime      Alex Burunova
# 1           Spanish   s2105  Movie      Dark Forces  Bernardo Arellano
#
#                                                 cast               country  \
# 0  Kozo Morishita, Yoko Takahashi, Shinji Aramaki...  United States, Japan
# 1  Tenoch Huerta, Eréndira Ibarra, Dale Carley, A...                Mexico
#
#         date_added  release_year rating duration  \
# 0   August 5, 2019          2019  TV-MA   59 min
# 1  August 21, 2020          2020  TV-MA   81 min
#
#                                            listed_in  \
# 0                Documentaries, International Movies
# ...

# %%
filtro_lanzamiento= netflix_concat["type"] == "Movie"
filtro_release= netflix_concat["release_year"] == 2021
netflix_concat[filtro_lanzamiento & filtro_release].head(3)
# Out:
#                         Title     Genre           Premiere  Runtime  \
# 9          Sardar Ka Grandson    Comedy       May 18, 2021      139
# 17  What Happened to Mr. Cha?    Comedy    January 1, 2021      102
# 21      The Girl on the Train  Thriller  February 26, 2021      120
#
#     IMDB Score Language show_id   type                      title  \
# 9          4.1    Hindi    s872  Movie         Sardar Ka Grandson
# 17         4.3   Korean   s1469  Movie  What Happened to Mr. Cha?
# 21         4.4    Hindi   s1266  Movie      The Girl on the Train
#
#           director                                               cast  \
# 9    Kaashvie Nair  Arjun Kapoor, Neena Gupta, Rakul Preet Singh, ...
# 17    Kim Dong-kyu           Cha In-pyo, Cho Dal-hwan, Song Jae-ryong
# 21  Ribhu Dasgupta  Parineeti Chopra, Aditi Rao Hydari, Kirti Kulh...
#
#         country         date_added  release_year rating duration  \
# 9         India       May 18, 2021          2021  TV-14  140 min
# ...

# %% [markdown]
# #### Ejercicio 2: ¿Qué títulos tienen una duración de 90 minutos? Muestra solo las columnas de título y de duración.

# %%
filtro_duración= netflix_concat["duration"] == 90
netflix_concat[filtro_duración]["title"]
# Out:
# Series([], Name: title, dtype: object)

# %% [markdown]
# #### Ejercicio 3: ¿Cuáles son todos los títulos del país 'India' lanzados después de 2018?

# %%
filtro_año= netflix_concat["release_year"] > 2018
filtro_país= netflix_concat["country"] == "India"
netflix_concat[filtro_año & filtro_país]["title"]
# Out:
# 4                         Kaali Khuhi
# 5                               Drive
# 9                  Sardar Ka Grandson
# 15                      Ghost Stories
# 21              The Girl on the Train
# 42                 Mrs. Serial Killer
# 65                          Firebrand
# 81     Gunjan Saxena: The Kargil Girl
# 92                             Guilty
# 104                      House Arrest
# 138                  Ginny Weds Sunny
# 151                         15 August
# 158           Choked: Paisa Bolta Hai
# 159                      Class of '83
# 186                             Maska
# 248                             Cargo
# 253                     Music Teacher
# 299                        Chopsticks
# 319                           Bulbbul
# 325                         Milestone
# 336                   Ajeeb Daastaans
# 355                          Upstarts
# 370                       Serious Men
# 377                          AK vs AK
# 385                          Pagglait
# ...

# %% [markdown]
# #### Ejercicio 4: ¿Qué títulos tienen clasificación 'TV-14' o 'R'?

# %%
filtro_clasifiacion= ["TV-14", "R"]
netflix_concat[netflix_concat["rating"].isin(filtro_clasifiacion)].filter(items= ["title"])
# Out:
#                         title
# 4                 Kaali Khuhi
# 5                       Drive
# 9          Sardar Ka Grandson
# 11                    Whipped
# 16   The Last Thing He Wanted
# ..                        ...
# 498             A Secret Love
# 500            Marriage Story
# 501            The Ivory Game
# 506                Seaspiracy
# 508    Cuba and the Cameraman
#
# [141 rows x 1 columns]

# %% [markdown]
# #### Ejercicio 5: ¿Cuáles son los títulos dirigidos por 'Christopher Nolan' o 'Martin Scorsese'? ¿Cuántos ha dirigido cada uno de los directores?

# %%
netflix_concat["director"].unique()
# Out:
# array(['Alex Burunova', 'Bernardo Arellano', 'Elisa Fuksas',
#        'Matt Angel, Suzanne Coote', 'Terrie Samundra', 'Tarun Mansukhani',
#        nan, 'Olivier Megaton', 'Daryl Hannah', 'Kaashvie Nair',
#        'Lee Chung-hyun', 'Chandra Liow', 'Adrian Teh', 'Chris Sparling',
#        'Rodrigo Reyes',
#        'Anurag Kashyap, Dibakar Banerjee, Karan Johar, Zoya Akhtar',
#        'Dee Rees', 'Kim Dong-kyu', 'Adam Wingard', 'Peter Sullivan',
#        'Michael Tiddes', 'Ribhu Dasgupta', 'Ben Falcone',
#        'Appie Boudellah, Aram van de Rest',
#        'Katleho Ramaphakela, Rethabile Ramaphakela', 'Julien Royal',
#        'Marco Risi', 'Nadia Hallgren', 'Osgood Perkins',
#        'Elisabeth Vogler', 'Zak Hilditch', 'Stefano Mordini',
#        'Stéphane de Freitas', 'Marla M. Ancheta', 'Jonathan Helpert',
#        'Julien Leclercq', 'Akira Saitoh', 'Domenico de Feudis',
#        'Robert Rodriguez', 'Detlev Buck', 'Emily Hagins',
# ...

# %%
netflix_concat["director"] == "Christopher Nolan"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 508    False
# 509    False
# 510    False
# 511    False
# 512    False
# Name: director, Length: 513, dtype: bool

# %%
lista_director= ["Christopher Nolan", "Martin Scorsese"]
titulos_chris_martin= netflix_concat[netflix_concat["director"].isin(lista_director)]
titulos_chris_martin.value_counts().sum()
# Out:
# np.int64(1)

# %% [markdown]
# #### Ejercicio 6: ¿Qué títulos pertenecen a los países 'United States', 'United Kingdom' o 'Canada'? Dentro de estos países, ¿cuántas películas tienen más de un lenguaje?

# %%
netflix_concat["Language"].value_counts()
# Out:
# Language
# English                       352
# Hindi                          28
# Spanish                        26
# French                         18
# Italian                        14
# Portuguese                      9
# Indonesian                      9
# Japanese                        5
# English/Spanish                 5
# Korean                          5
# Turkish                         4
# German                          4
# Marathi                         3
# Polish                          3
# English/Japanese                2
# Dutch                           2
# Filipino                        2
# Thai                            2
# English/Hindi                   2
# Norwegian                       1
# Malay                           1
# Swedish                         1
# Spanish/Basque                  1
# English/Swedish                 1
# Spanish/Catalan                 1
# English/Taiwanese/Mandarin      1
# Thia/English                    1
# ...

# %%
lista_paises= ["United States", "United Kingdom", "Canada"]
netflix_US_UK_CA= netflix_concat[netflix_concat["country"].isin(lista_paises)]
netflix_US_UK_CA.value_counts() #Para ver que veamos que titulos son de esos paises


patron_regex= "/"                                             
más_language= netflix_US_UK_CA["Language"].str.contains(patron_regex, case= False, na= False)     #El case = False hace que se budque research con minuscula y con mayuscula si se pone case= True solo dará las minusculas
netflix_US_UK_CA[más_language].value_counts().sum()  #Para que veamos cuantos de esos títulos tienen más de un lenguaje
# Out:
# np.int64(3)

# %% [markdown]
# #### Ejercicio 7: ¿Qué títulos fueron lanzados entre 2015 y 2020, inclusive?

# %%
filtro_rango_año= netflix_concat["release_year"].between(2015, 2020, inclusive= "both")
netflix_concat[filtro_rango_año].filter(items= ["title"])
# Out:
#                                            title
# 0                                Enter the Anime
# 1                                    Dark Forces
# 2                                        The App
# 3                                 The Open House
# 4                                    Kaali Khuhi
# ..                                           ...
# 508                       Cuba and the Cameraman
# 509                       Dancing with the Birds
# 510  Winter on Fire: Ukraine's Fight for Freedom
# 511                      Springsteen on Broadway
# 512     David Attenborough: A Life on Our Planet
#
# [456 rows x 1 columns]

# %% [markdown]
# #### Ejercicio 8: ¿Cuáles son los títulos cuya puntuación en IMDb está entre 6.5 y 8.0 y que no sepamos cual es su duración?

# %%
netflix_concat["IMDB Score"]
# Out:
# 0      2.5
# 1      2.6
# 2      2.6
# 3      3.2
# 4      3.4
#       ...
# 508    8.3
# 509    8.3
# 510    8.4
# 511    8.5
# 512    9.0
# Name: IMDB Score, Length: 513, dtype: float64

# %%
filtro_IMDB= netflix_concat["IMDB Score"].between(6.5, 8, inclusive= "neither" )
filtro_duracion= netflix_concat["duration"].isna()
netflix_concat[filtro_IMDB & filtro_duracion].head(3)
# Out:
#          Title                       Genre            Premiere  Runtime  \
# 317   Bad Trip  Hidden-camera prank comedy      March 26, 2021       86
# 319    Bulbbul                      Horror       June 24, 2020       94
# 331  The Angel                Spy thriller  September 14, 2018      114
#
#      IMDB Score Language show_id   type      title      director  \
# 317         6.6  English   s1158  Movie   Bad Trip           NaN
# 319         6.6    Hindi   s2343  Movie    Bulbbul   Anvita Dutt
# 331         6.6  English   s4642  Movie  The Angel  Ariel Vromen
#
#                                                   cast                country  \
# 317  Eric André, Lil Rel Howery, Tiffany Haddish, M...          United States
# 319  Tripti Dimri, Avinash Tiwary, Rahul Bose, Para...                  India
# 331  Marwan Kenzari, Hannah Ware, Toby Kebbell, Wal...  Israel, United States
#
#              date_added  release_year rating duration  \
# ...

# %% [markdown]
# #### Ejercicio 9: ¿Cuáles son las películas cuya duración de 90 o 150 minutos?

# %%
patron_regex1= "^150" 
patron_regex2="^90"                                   
_noventa=netflix_concat["duration"].str.contains(patron_regex2, case= False, na= False, regex= True)
_cientocincuenta=netflix_concat["duration"].str.contains(patron_regex1, case= False, na= False, regex= True)
total= _cientocincuenta | _noventa
netflix_concat[total].head(3)
# Out:
#                    Title     Genre       Premiere  Runtime  IMDB Score  \
# 23          Fatal Affair  Thriller  July 16, 2020       89         4.5
# 123  One-Way to Tomorrow   Romance  June 19, 2020       90         5.6
# 139             Good Sam     Drama   May 16, 2019       89         5.7
#
#     Language show_id   type                title        director  \
# 23   English   s2233  Movie         Fatal Affair  Peter Sullivan
# 123  Turkish   s2361  Movie  One-Way to Tomorrow    Ozan Açıktan
# 139  English   s3819  Movie             Good Sam   Kate Melville
#
#                                                   cast        country  \
# 23   Nia Long, Omar Epps, Stephen Bishop, Maya Stoj...  United States
# 123                  Dilan Çiçek Deniz, Metin Akdülger         Turkey
# 139  Tiya Sircar, Chad Connell, Marco Grazzini, Jes...  United States
#
#         date_added  release_year rating duration  \
# 23   July 16, 2020          2020  TV-14   90 min
# ...

# %%
_noventa.sum()
# Out:
# np.int64(13)

# %% [markdown]
# #### Ejercicio 10: ¿Cuáles son los títulos que contienen la palabra 'Love' en su título y que sean de tipo TV Show?

# %%
patron_regex= "Love"                                             
_love=netflix_concat["title"].str.contains(patron_regex, case= False, na= False)
netflix_concat[_love].head(3)
# Out:
#                           Title            Genre           Premiere  Runtime  \
# 53   Love Like the Falling Rain            Drama   October 15, 2020       86
# 55                 Squared Love  Romantic comedy  February 11, 2021      102
# 106         Love Wedding Repeat  Romantic comedy     April 10, 2020      100
#
#      IMDB Score    Language show_id   type                       title  \
# 53          5.0  Indonesian   s1851  Movie  Love Like the Falling Rain
# 55          5.0      Polish   s1327  Movie                Squared Love
# 106         5.5     English   s2694  Movie         Love Wedding Repeat
#
#                  director                                               cast  \
# 53   Lasja Fauzia Susatyo  Jefri Nichol, Aurora Ribero, Axel Matthew, Nad...
# 55           Filip Zylber  Adrianna Chlebicka, Mateusz Banasiuk, Agnieszk...
# 106            Dean Craig  Sam Claflin, Olivia Munn, Freida Pinto, Eleano...
#
# ...

# %% [markdown]
# #### Ejercicio 11: ¿Cuáles son los títulos en los que el director tiene el apellido 'Johnson'?

# %%
patron_regex= "Johnson"                                             
apellido=netflix_concat["director"].str.contains(patron_regex, case= False, na= False)
netflix_concat[apellido].head(3)
# Out:
#                 Title            Genre           Premiere  Runtime  \
# 122  Love, Guaranteed  Romantic comedy  September 3, 2020       91
# 195           Juanita            Drama      March 8, 2019       90
# 244  Alex Strangelove  Romantic comedy       June 8, 2018       99
#
#      IMDB Score Language show_id   type             title  \
# 122         5.6  English   s2053  Movie  Love, Guaranteed
# 195         6.0  English   s4034  Movie           Juanita
# 244         6.3  English   s4834  Movie  Alex Strangelove
#
#                 director                                               cast  \
# 122  Mark Steven Johnson  Rachael Leigh Cook, Damon Wayans Jr., Heather ...
# 195        Clark Johnson  Alfre Woodard, Adam Beach, LaTanya Richardson ...
# 244        Craig Johnson  Daniel Doheny, Madeline Weinstein, Antonio Mar...
#
#            country         date_added  release_year rating duration  \
# 122  United States  September 3, 2020          2020  TV-PG      NaN
# ...

# %% [markdown]
# #### Ejercicio 12: ¿Tenemos algún documental ('Documentaries') de Mike Tyson?

# %%
filtro_cast= netflix_concat["cast"] == "Mike Tyson"
filtro_genre= netflix_concat["Genre"] == "Documentary"    #Creo que el código no está mal simplemnete es cosa de mi base de datos q no tenga mike
netflix_concat[filtro_cast & filtro_genre]
# Out:
# Empty DataFrame
# Columns: [Title, Genre, Premiere, Runtime, IMDB Score, Language, show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
filtro_genre.sum()
# Out:
# np.int64(132)

# %%
filtro_cast.sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Ejercicio 13: Selecciona solo las columnas 'title', 'country' y 'release_year' del dataset.

# %%
netflix_concat[["title", "country", "release_year"]]
# Out:
#                                            title  \
# 0                                Enter the Anime
# 1                                    Dark Forces
# 2                                        The App
# 3                                 The Open House
# 4                                    Kaali Khuhi
# ..                                           ...
# 508                       Cuba and the Cameraman
# 509                       Dancing with the Birds
# 510  Winter on Fire: Ukraine's Fight for Freedom
# 511                      Springsteen on Broadway
# 512     David Attenborough: A Life on Our Planet
#
#                                     country  release_year
# 0                      United States, Japan          2019
# 1                                    Mexico          2020
# 2                                     Italy          2019
# 3                     Canada, United States          2018
# 4                                     India          2020
# ...

# %% [markdown]
# #### Ejercicio 14: Filtra las columnas que contienen la palabra 'date'.

# %%
netflix_concat.str.contains(patron_regex, case= False, )
patron_regex= "date"                                             
apellido=netflix_concat["director"].str.contains(patron_regex, case= False, na= False)
netflix_concat[apellido]

# %%
netflix_concat.filter(like = "date")
# Out:
#             date_added
# 0       August 5, 2019
# 1      August 21, 2020
# 2    December 26, 2019
# 3     January 19, 2018
# 4     October 30, 2020
# ..                 ...
# 508  November 24, 2017
# 509   October 23, 2019
# 510    October 9, 2015
# 511  December 16, 2018
# 512    October 4, 2020
#
# [513 rows x 1 columns]

# %% [markdown]
# #### Ejercicio 15: Usando `query()`, filtra todos los títulos del país 'France' con una duración de 80 minutos.

# %%
netflix_concat.columns
# Out:
# Index(['Title', 'Genre', 'Premiere', 'Runtime', 'IMDB Score', 'Language',
#        'show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
netflix_concat_query= netflix_concat.query("country == 'France' and duration == '80 min'")[["title"]]             
netflix_concat_query.head()
# Out:
# Empty DataFrame
# Columns: [title]
# Index: []

# %% [markdown]
# #### Ejercicio 16: Filtra los títulos que son películas ('Movie') y fueron lanzados antes de 2010.

# %%
filtro_type= netflix_concat["type"] == "Movie"          #El código creo que está bien porque si pongo por ejemplo 2015 si que me sale
filtro_ryear= netflix_concat["release_year"] < 2010
netflix_concat[filtro_type & filtro_ryear]
# Out:
# Empty DataFrame
# Columns: [Title, Genre, Premiere, Runtime, IMDB Score, Language, show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# #### Ejercicio 17: Encuentra los 10 títulos con las puntuaciones más altas en IMDb.

# %%
netflix_ordenado= netflix_concat["IMDB Score"].sort_values(axis= 0, ascending= True)
netflix_ordenado[-10:]
# Out:
# 502    8.1
# 504    8.1
# 507    8.2
# 506    8.2
# 505    8.2
# 509    8.3
# 508    8.3
# 510    8.4
# 511    8.5
# 512    9.0
# Name: IMDB Score, dtype: float64

# %%
netflix_concat.nlargest(10, columns= "IMDB Score").filter(items= ["title"])
# Out:
#                                            title
# 512     David Attenborough: A Life on Our Planet
# 511                      Springsteen on Broadway
# 510  Winter on Fire: Ukraine's Fight for Freedom
# 508                       Cuba and the Cameraman
# 509                       Dancing with the Birds
# 505                                        Klaus
# 506                                   Seaspiracy
# 507        The Three Deaths of Marisela Escobedo
# 502                                Chasing Coral
# 503                           My Octopus Teacher

# %% [markdown]
# #### Ejercicio 18: Encuentra los 5 títulos con las puntuaciones más bajas en IMDb.

# %%
netflix_concat.nsmallest(5, columns= "IMDB Score")["title"]
# Out:
# 0    Enter the Anime
# 1        Dark Forces
# 2            The App
# 3     The Open House
# 4        Kaali Khuhi
# Name: title, dtype: object

# %% [markdown]
# #### Ejercicio 19: Filtra todos los títulos que no tienen un director asignado (valores nulos en la columna 'director').

# %%
sin_director= netflix_concat["director"].isna()
netflix_concat[sin_director]["title"]
# Out:
# 6                                      Leyla Everlasting
# 62      American Factory: A Conversation with the Obamas
# 64                                    Father of the Year
# 188                         The Minimalists: Less Is Now
# 201                                  The Princess Switch
# 214                                            Otherhood
# 218                                          Stuck Apart
# 256                                                Polar
# 276                    John Was Trying to Contact Aliens
# 278             Murder to Mercy: The Cyntoia Brown Story
# 297            Antoine Griezmann: The Making of a Legend
# 301                    Dolly Parton: A MusiCares Tribute
# 317                                             Bad Trip
# 372             The Boys in the Band: Something Personal
# 398    Ma Rainey's Black Bottom: A Legacy Brought to ...
# 413                              Derren Brown: Sacrifice
# ...

# %% [markdown]
# #### Ejercicio 20: Filtra todos los títulos que tienen información completa en las columnas 'title', 'country' y 'IMDB Score'.

# %%
titlenotnull= netflix_concat["title"].notnull()
countrynotnull= netflix_concat["country"].notnull()
IMDBnotnull= netflix_concat["IMDB Score"].notnull()
netflix_concat[titlenotnull & countrynotnull & IMDBnotnull].head(3)
# Out:
#              Title                  Genre           Premiere  Runtime  \
# 0  Enter the Anime            Documentary     August 5, 2019       58
# 1      Dark Forces               Thriller    August 21, 2020       81
# 2          The App  Science fiction/Drama  December 26, 2019       79
#
#    IMDB Score          Language show_id   type            title  \
# 0         2.5  English/Japanese   s3624  Movie  Enter the Anime
# 1         2.6           Spanish   s2105  Movie      Dark Forces
# 2         2.6           Italian   s3095  Movie          The App
#
#             director                                               cast  \
# 0      Alex Burunova  Kozo Morishita, Yoko Takahashi, Shinji Aramaki...
# 1  Bernardo Arellano  Tenoch Huerta, Eréndira Ibarra, Dale Carley, A...
# 2       Elisa Fuksas  Vincenzo Crea, Jessica Cressy, Greta Scarano, ...
#
#                 country         date_added  release_year rating duration  \
# ...

# %% [markdown]
# #### Ejercicio 21: Identifica si hay títulos duplicados en la columna 'title'.

# %%
duplicados= netflix_concat["title"].duplicated()
duplicados.sum()                               #No
# Out:
# np.int64(0)
